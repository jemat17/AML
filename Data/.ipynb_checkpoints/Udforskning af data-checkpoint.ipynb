# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
pd.__version__

# Style 
plt.style.use('ggplot')
# %matplotlib inline

# %%
df_labels = pd.read_csv('labels.txt',sep='\n', delimiter=',', header=None )

# %% [markdown]
# # Function to remove dublicates from labels.

# %%
def uniquify(df_columns):
    df_columns = df_columns.T.iloc[0,:]
    seen = list()

    for item in df_columns:
        fudge = 'hand'
        newitem = item
        
        if newitem in seen:
            newitem = "{}_{}".format(item, fudge)

        seen.append(newitem)
    return seen
        
label_list = uniquify(df_labels)
display(label_list)
# Out:
# ['Subject index (1-40)',
#  'ECG_original_mean',
#  'ECG_original_std',
#  'ECG_original_trimmean25',
#  'ECG_original_median',
#  'ECG_original_skewness',
#  'ECG_original_kurtosis',
#  'ECG_original_max',
#  'ECG_original_min',
#  'ECG_original_prctile25',
#  'ECG_original_prctile75',
#  'ECG_original_geomean(abs)',
#  'ECG_original_harmmean',
#  'ECG_original_mad',
#  'ECG_original_baseline',
#  'ECG_RR_window_mean',
#  'ECG_RR_window_std',
#  'ECG_RR_window_trimmean25',
#  'ECG_RR_window_median',
#  'ECG_RR_window_skewness',
#  'ECG_RR_window_kurtosis',
#  'ECG_RR_window_max',
#  'ECG_RR_window_min',
#  'ECG_RR_window_prctile25',
#  'ECG_RR_window_prctile75',
#  'ECG_RR_window_geomean(abs)',
#  'ECG_RR_window_harmmean',
#  'ECG_RR_window_mad',
#  'ECG_RR_window_baseline',
#  'ECG_amplitude_RR_mean',
#  'ECG_amplitude_RR_std',
#  'ECG_amplitude_RR_trimmean25',
#  'ECG_amplitude_RR_median',
#  'ECG_amplitude_RR_skewness',
#  'ECG_amplitude_RR_kurtosis',
#  'ECG_amplitude_RR_max',
#  'ECG_amplitude_RR_min',
#  'ECG_amplitude_RR_prctile25',
#  'ECG_amplitude_RR_prctile75',
#  'ECG_amplitude_RR_geomean(abs)',
#  'ECG_amplitude_RR_harmmean',
#  'ECG_amplitude_RR_mad',
#  'ECG_amplitude_RR_baseline',
#  'ECG_HR_min_div_mean',
#  'ECG_HR_min_div_std',
#  'ECG_HR_min_div_trimmean25',
#  'ECG_HR_min_div_median',
#  'ECG_HR_min_div_skewness',
#  'ECG_HR_min_div_kurtosis',
#  'ECG_HR_min_div_max',
#  'ECG_HR_min_div_min',
#  'ECG_HR_min_div_prctile25',
#  'ECG_HR_min_div_prctile75',
#  'ECG_HR_min_div_geomean(abs)',
#  'ECG_HR_min_div_harmmean',
#  'ECG_HR_min_div_mad',
#  'ECG_HR_min_div_baseline',
#  'ECG_DBD',
#  'ECG_EI',
#  'ECG_IE',
#  'ECG_Logstd',
#  'ECG_RSAindex',
#  'ECG_M',
#  'ECG_Load_index',
#  'ECG_NN50',
#  'ECG_pNN50',
#  'ECG_Entropyaprox',
#  'ECG_hrv_mean',
#  'ECG_hrv_std',
#  'ECG_hrv_trimmean25',
#  'ECG_hrv_median',
#  'ECG_hrv_skewness',
#  'ECG_hrv_kurtosis',
#  'ECG_hrv_max',
#  'ECG_hrv_min',
#  'ECG_hrv_prctile25',
#  'ECG_hrv_prctile75',
#  'ECG_hrv_geomean(abs)',
#  'ECG_hrv_harmmean',
#  'ECG_hrv_mad',
#  'ECG_hrv_baseline',
#  'ECG_PSD_mean',
#  'ECG_PSD_std',
#  'ECG_PSD_trimmean25',
#  'ECG_PSD_median',
#  'ECG_PSD_skewness',
#  'ECG_PSD_kurtosis',
#  'ECG_PSD_max',
#  'ECG_PSD_min',
#  'ECG_PSD_prctile25',
#  'ECG_PSD_prctile75',
#  'ECG_PSD_geomean(abs)',
#  'ECG_PSD_harmmean',
#  'ECG_PSD_mad',
#  'ECG_PSD_baseline',
#  'ECG_p_VFL_mean',
#  'ECG_p_VFL_std',
#  'ECG_p_VFL_trimmean25',
#  'ECG_p_VFL_median',
#  'ECG_p_VFL_skewness',
#  'ECG_p_VFL_kurtosis',
#  'ECG_p_VFL_max',
#  'ECG_p_VFL_min',
#  'ECG_p_VFL_prctile25',
#  'ECG_p_VFL_prctile75',
#  'ECG_p_VFL_geomean(abs)',
#  'ECG_p_VFL_harmmean',
#  'ECG_p_VFL_mad',
#  'ECG_p_VFL_baseline',
#  'ECG_p_LF_mean',
#  'ECG_p_LF_std',
#  'ECG_p_LF_trimmean25',
#  'ECG_p_LF_median',
#  'ECG_p_LF_skewness',
#  'ECG_p_LF_kurtosis',
#  'ECG_p_LF_max',
#  'ECG_p_LF_min',
#  'ECG_p_LF_prctile25',
#  'ECG_p_LF_prctile75',
#  'ECG_p_LF_geomean(abs)',
#  'ECG_p_LF_harmmean',
#  'ECG_p_LF_mad',
#  'ECG_p_LF_baseline',
#  'ECG_p_MF_mean',
#  'ECG_p_MF_std',
#  'ECG_p_MF_trimmean25',
#  'ECG_p_MF_median',
#  'ECG_p_MF_skewness',
#  'ECG_p_MF_kurtosis',
#  'ECG_p_MF_max',
#  'ECG_p_MF_min',
#  'ECG_p_MF_prctile25',
#  'ECG_p_MF_prctile75',
#  'ECG_p_MF_geomean(abs)',
#  'ECG_p_MF_harmmean',
#  'ECG_p_MF_mad',
#  'ECG_p_MF_baseline',
#  'ECG_p_HF_mean',
#  'ECG_p_HF_std',
#  'ECG_p_HF_trimmean25',
#  'ECG_p_HF_median',
#  'ECG_p_HF_skewness',
#  'ECG_p_HF_kurtosis',
#  'ECG_p_HF_max',
#  'ECG_p_HF_min',
#  'ECG_p_HF_prctile25',
#  'ECG_p_HF_prctile75',
#  'ECG_p_HF_geomean(abs)',
#  'ECG_p_HF_harmmean',
#  'ECG_p_HF_mad',
#  'ECG_p_HF_baseline',
#  'ECG_p_total_LF_mean',
#  'ECG_p_total_LF_std',
#  'ECG_p_total_LF_trimmean25',
#  'ECG_p_total_LF_median',
#  'ECG_p_total_LF_skewness',
#  'ECG_p_total_LF_kurtosis',
#  'ECG_p_total_LF_max',
#  'ECG_p_total_LF_min',
#  'ECG_p_total_LF_prctile25',
#  'ECG_p_total_LF_prctile75',
#  'ECG_p_total_LF_geomean(abs)',
#  'ECG_p_total_LF_harmmean',
#  'ECG_p_total_LF_mad',
#  'ECG_p_total_LF_baseline',
#  'ECG_HF_LF',
#  'ECG_LF_HF',
#  'ECG_MF_HF',
#  'ECG_HF_TF',
#  'ECG_LF_MF_HF',
#  'ECG_CCV_LF',
#  'ECG_CCV_HF',
#  'ECG_RMSSDD',
#  'ECG_A1_DFA',
#  'ECG_A2_DFA',
#  'IT_Original_mean',
#  'IT_Original_std',
#  'IT_Original_trimmean25',
#  'IT_Original_median',
#  'IT_Original_skewness',
#  'IT_Original_kurtosis',
#  'IT_Original_max',
#  'IT_Original_min',
#  'IT_Original_prctile25',
#  'IT_Original_prctile75',
#  'IT_Original_geomean(abs)',
#  'IT_Original_harmmean',
#  'IT_Original_mad',
#  'IT_Original_baseline',
#  'IT_Original_Area',
#  'IT_LF_mean',
#  'IT_LF_std',
#  'IT_LF_trimmean25',
#  'IT_LF_median',
#  'IT_LF_skewness',
#  'IT_LF_kurtosis',
#  'IT_LF_max',
#  'IT_LF_min',
#  'IT_LF_prctile25',
#  'IT_LF_prctile75',
#  'IT_LF_geomean(abs)',
#  'IT_LF_harmmean',
#  'IT_LF_mad',
#  'IT_LF_baseline',
#  'IT_LF_Area',
#  'IT_RF_mean',
#  'IT_RF_std',
#  'IT_RF_trimmean25',
#  'IT_RF_median',
#  'IT_RF_skewness',
#  'IT_RF_kurtosis',
#  'IT_RF_max',
#  'IT_RF_min',
#  'IT_RF_prctile25',
#  'IT_RF_prctile75',
#  'IT_RF_geomean(abs)',
#  'IT_RF_harmmean',
#  'IT_RF_mad',
#  'IT_RF_baseline',
#  'IT_RF_Area',
#  'IT_BR_mean',
#  'IT_BRV_mean',
#  'IT_BRV_std',
#  'IT_BRV_trimmean25',
#  'IT_BRV_median',
#  'IT_BRV_skewness',
#  'IT_BRV_kurtosis',
#  'IT_BRV_max',
#  'IT_BRV_min',
#  'IT_BRV_prctile25',
#  'IT_BRV_prctile75',
#  'IT_BRV_geomean(abs)',
#  'IT_BRV_harmmean',
#  'IT_BRV_mad',
#  'IT_BRV_baseline',
#  'IT_PSD_mean',
#  'IT_PSD_std',
#  'IT_PSD_trimmean25',
#  'IT_PSD_median',
#  'IT_PSD_skewness',
#  'IT_PSD_kurtosis',
#  'IT_PSD_max',
#  'IT_PSD_min',
#  'IT_PSD_prctile25',
#  'IT_PSD_prctile75',
#  'IT_PSD_geomean(abs)',
#  'IT_PSD_harmmean',
#  'IT_PSD_mad',
#  'IT_PSD_baseline',
#  'IT_VLF_mean',
#  'IT_VLF_std',
#  'IT_VLF_trimmean25',
#  'IT_VLF_median',
#  'IT_VLF_skewness',
#  'IT_VLF_kurtosis',
#  'IT_VLF_max',
#  'IT_VLF_min',
#  'IT_VLF_prctile25',
#  'IT_VLF_prctile75',
#  'IT_VLF_geomean(abs)',
#  'IT_VLF_harmmean',
#  'IT_VLF_mad',
#  'IT_VLF_baseline',
#  'IT_LF_mean_hand',
#  'IT_LF_std_hand',
#  'IT_LF_trimmean25_hand',
#  'IT_LF_median_hand',
#  'IT_LF_skewness_hand',
#  'IT_LF_kurtosis_hand',
#  'IT_LF_max_hand',
#  'IT_LF_min_hand',
#  'IT_LF_prctile25_hand',
#  'IT_LF_prctile75_hand',
#  'IT_LF_geomean(abs)_hand',
#  'IT_LF_harmmean_hand',
#  'IT_LF_mad_hand',
#  'IT_LF_baseline_hand',
#  'IT_MF_mean',
#  'IT_MF_std',
#  'IT_MF_trimmean25',
#  'IT_MF_median',
#  'IT_MF_skewness',
#  'IT_MF_kurtosis',
#  'IT_MF_max',
#  'IT_MF_min',
#  'IT_MF_prctile25',
#  'IT_MF_prctile75',
#  'IT_MF_geomean(abs)',
#  'IT_MF_harmmean',
#  'IT_MF_mad',
#  'IT_MF_baseline',
#  'IT_HF_mean',
#  'IT_HF_std',
#  'IT_HF_trimmean25',
#  'IT_HF_median',
#  'IT_HF_skewness',
#  'IT_HF_kurtosis',
#  'IT_HF_max',
#  'IT_HF_min',
#  'IT_HF_prctile25',
#  'IT_HF_prctile75',
#  'IT_HF_geomean(abs)',
#  'IT_HF_harmmean',
#  'IT_HF_mad',
#  'IT_HF_baseline',
#  'IT_p_Total_mean',
#  'IT_p_Total_std',
#  'IT_p_Total_trimmean25',
#  'IT_p_Total_median',
#  'IT_p_Total_skewness',
#  'IT_p_Total_kurtosis',
#  'IT_p_Total_max',
#  'IT_p_Total_min',
#  'IT_p_Total_prctile25',
#  'IT_p_Total_prctile75',
#  'IT_p_Total_geomean(abs)',
#  'IT_p_Total_harmmean',
#  'IT_p_Total_mad',
#  'IT_p_Total_baseline',
#  'IT_HF_LF',
#  'IT_LF_HF',
#  'IT_MF_HF',
#  'IT_HF_TF',
#  'IT_LF_MF_HF',
#  'IT_CCV_LF',
#  'IT_CCV_HF',
#  'EDA_Original_mean',
#  'EDA_Original_std',
#  'EDA_Original_trimmean25',
#  'EDA_Original_median',
#  'EDA_Original_skewness',
#  'EDA_Original_kurtosis',
#  'EDA_Original_max',
#  'EDA_Original_min',
#  'EDA_Original_prctile25',
#  'EDA_Original_prctile75',
#  'EDA_Original_geomean(abs)',
#  'EDA_Original_harmmean',
#  'EDA_Original_mad',
#  'EDA_Original_baseline',
#  'EDA_processed_mean',
#  'EDA_processed_std',
#  'EDA_processed_trimmean25',
#  'EDA_processed_median',
#  'EDA_processed_skewness',
#  'EDA_processed_kurtosis',
#  'EDA_processed_max',
#  'EDA_processed_min',
#  'EDA_processed_prctile25',
#  'EDA_processed_prctile75',
#  'EDA_processed_geomean(abs)',
#  'EDA_processed_harmmean',
#  'EDA_processed_mad',
#  'EDA_processed_baseline',
#  'EDA_Filt1_mean',
#  'EDA_Filt1_std',
#  'EDA_Filt1_trimmean25',
#  'EDA_Filt1_median',
#  'EDA_Filt1_skewness',
#  'EDA_Filt1_kurtosis',
#  'EDA_Filt1_max',
#  'EDA_Filt1_min',
#  'EDA_Filt1_prctile25',
#  'EDA_Filt1_prctile75',
#  'EDA_Filt1_geomean(abs)',
#  'EDA_Filt1_harmmean',
#  'EDA_Filt1_mad',
#  'EDA_Filt1_baseline',
#  'EDA_Filt2_mean',
#  'EDA_Filt2_std',
#  'EDA_Filt2_trimmean25',
#  'EDA_Filt2_median',
#  'EDA_Filt2_skewness',
#  'EDA_Filt2_kurtosis',
#  'EDA_Filt2_max',
#  'EDA_Filt2_min',
#  'EDA_Filt2_prctile25',
#  'EDA_Filt2_prctile75',
#  'EDA_Filt2_geomean(abs)',
#  'EDA_Filt2_harmmean',
#  'EDA_Filt2_mad',
#  'EDA_Filt2_baseline',
#  'EDA_cross_pos',
#  'EDA_cross_neg',
#  'EDA_n_ocu',
#  'EDA_amp_scr',
#  'EDA_p_samples',
#  'EDA_area',
#  'EDA_Functionals_power_Originalmean',
#  'EDA_Functionals_power_Originalstd',
#  'EDA_Functionals_power_Originaltrimmean25',
#  'EDA_Functionals_power_Originalmedian',
#  'EDA_Functionals_power_Originalskewness',
#  'EDA_Functionals_power_Originalkurtosis',
#  'EDA_Functionals_power_Originalmax',
#  'EDA_Functionals_power_Originalmin',
#  'EDA_Functionals_power_Originalprctile25',
#  'EDA_Functionals_power_Originalprctile75',
#  'EDA_Functionals_power_Originalgeomean(abs)',
#  'EDA_Functionals_power_Originalharmmean',
#  'EDA_Functionals_power_Originalmad',
#  'EDA_Functionals_power_Originalbaseline',
#  'EDA_Functionals_power_Fil12mean',
#  'EDA_Functionals_power_Fil12std',
#  'EDA_Functionals_power_Fil12trimmean25',
#  'EDA_Functionals_power_Fil12median',
#  'EDA_Functionals_power_Fil12skewness',
#  'EDA_Functionals_power_Fil12kurtosis',
#  'EDA_Functionals_power_Fil12max',
#  'EDA_Functionals_power_Fil12min',
#  'EDA_Functionals_power_Fil12prctile25',
#  'EDA_Functionals_power_Fil12prctile75',
#  'EDA_Functionals_power_Fil12geomean(abs)',
#  'EDA_Functionals_power_Fil12harmmean',
#  'EDA_Functionals_power_Fil12mad',
#  'EDA_Functionals_power_Fil12baseline',
#  'EDA_Functionals_power_Filt2mean',
#  'EDA_Functionals_power_Filt2std',
#  'EDA_Functionals_power_Filt2trimmean25',
#  'EDA_Functionals_power_Filt2median',
#  'EDA_Functionals_power_Filt2skewness',
#  'EDA_Functionals_power_Filt2kurtosis',
#  'EDA_Functionals_power_Filt2max',
#  'EDA_Functionals_power_Filt2min',
#  'EDA_Functionals_power_Filt2prctile25',
#  'EDA_Functionals_power_Filt2prctile75',
#  'EDA_Functionals_power_Filt2geomean(abs)',
#  'EDA_Functionals_power_Filt2harmmean',
#  'EDA_Functionals_power_Filt2mad',
#  'EDA_Functionals_power_Filt2baseline',
#  'EDA_Original_mean_hand',
#  'EDA_Original_std_hand',
#  'EDA_Original_trimmean25_hand',
#  'EDA_Original_median_hand',
#  'EDA_Original_skewness_hand',
#  'EDA_Original_kurtosis_hand',
#  'EDA_Original_max_hand',
#  'EDA_Original_min_hand',
#  'EDA_Original_prctile25_hand',
#  'EDA_Original_prctile75_hand',
#  'EDA_Original_geomean(abs)_hand',
#  'EDA_Original_harmmean_hand',
#  'EDA_Original_mad_hand',
#  'EDA_Original_baseline_hand',
#  'EDA_processed_mean_hand',
#  'EDA_processed_std_hand',
#  'EDA_processed_trimmean25_hand',
#  'EDA_processed_median_hand',
#  'EDA_processed_skewness_hand',
#  'EDA_processed_kurtosis_hand',
#  'EDA_processed_max_hand',
#  'EDA_processed_min_hand',
#  'EDA_processed_prctile25_hand',
#  'EDA_processed_prctile75_hand',
#  'EDA_processed_geomean(abs)_hand',
#  'EDA_processed_harmmean_hand',
#  'EDA_processed_mad_hand',
#  'EDA_processed_baseline_hand',
#  'EDA_Filt1_mean_hand',
#  'EDA_Filt1_std_hand',
#  'EDA_Filt1_trimmean25_hand',
#  'EDA_Filt1_median_hand',
#  'EDA_Filt1_skewness_hand',
#  'EDA_Filt1_kurtosis_hand',
#  'EDA_Filt1_max_hand',
#  'EDA_Filt1_min_hand',
#  'EDA_Filt1_prctile25_hand',
#  'EDA_Filt1_prctile75_hand',
#  'EDA_Filt1_geomean(abs)_hand',
#  'EDA_Filt1_harmmean_hand',
#  'EDA_Filt1_mad_hand',
#  'EDA_Filt1_baseline_hand',
#  'EDA_Filt2_mean_hand',
#  'EDA_Filt2_std_hand',
#  'EDA_Filt2_trimmean25_hand',
#  'EDA_Filt2_median_hand',
#  'EDA_Filt2_skewness_hand',
#  'EDA_Filt2_kurtosis_hand',
#  'EDA_Filt2_max_hand',
#  'EDA_Filt2_min_hand',
#  'EDA_Filt2_prctile25_hand',
#  'EDA_Filt2_prctile75_hand',
#  'EDA_Filt2_geomean(abs)_hand',
#  'EDA_Filt2_harmmean_hand',
#  'EDA_Filt2_mad_hand',
#  'EDA_Filt2_baseline_hand',
#  'EDA_cross_pos_hand',
#  'EDA_cross_neg_hand',
#  'EDA_n_ocu_hand',
#  'EDA_amp_scr_hand',
#  'EDA_p_samples_hand',
#  'EDA_area_hand',
#  'EDA_Functionals_power_Originalmean_hand',
#  'EDA_Functionals_power_Originalstd_hand',
#  'EDA_Functionals_power_Originaltrimmean25_hand',
#  'EDA_Functionals_power_Originalmedian_hand',
#  'EDA_Functionals_power_Originalskewness_hand',
#  'EDA_Functionals_power_Originalkurtosis_hand',
#  'EDA_Functionals_power_Originalmax_hand',
#  'EDA_Functionals_power_Originalmin_hand',
#  'EDA_Functionals_power_Originalprctile25_hand',
#  'EDA_Functionals_power_Originalprctile75_hand',
#  'EDA_Functionals_power_Originalgeomean(abs)_hand',
#  'EDA_Functionals_power_Originalharmmean_hand',
#  'EDA_Functionals_power_Originalmad_hand',
#  'EDA_Functionals_power_Originalbaseline_hand',
#  'EDA_Functionals_power_Fil12mean_hand',
#  'EDA_Functionals_power_Fil12std_hand',
#  'EDA_Functionals_power_Fil12trimmean25_hand',
#  'EDA_Functionals_power_Fil12median_hand',
#  'EDA_Functionals_power_Fil12skewness_hand',
#  'EDA_Functionals_power_Fil12kurtosis_hand',
#  'EDA_Functionals_power_Fil12max_hand',
#  'EDA_Functionals_power_Fil12min_hand',
#  'EDA_Functionals_power_Fil12prctile25_hand',
#  'EDA_Functionals_power_Fil12prctile75_hand',
#  'EDA_Functionals_power_Fil12geomean(abs)_hand',
#  'EDA_Functionals_power_Fil12harmmean_hand',
#  'EDA_Functionals_power_Fil12mad_hand',
#  'EDA_Functionals_power_Fil12baseline_hand',
#  'EDA_Functionals_power_Filt2mean_hand',
#  'EDA_Functionals_power_Filt2std_hand',
#  'EDA_Functionals_power_Filt2trimmean25_hand',
#  'EDA_Functionals_power_Filt2median_hand',
#  'EDA_Functionals_power_Filt2skewness_hand',
#  'EDA_Functionals_power_Filt2kurtosis_hand',
#  'EDA_Functionals_power_Filt2max_hand',
#  'EDA_Functionals_power_Filt2min_hand',
#  'EDA_Functionals_power_Filt2prctile25_hand',
#  'EDA_Functionals_power_Filt2prctile75_hand',
#  'EDA_Functionals_power_Filt2geomean(abs)_hand',
#  'EDA_Functionals_power_Filt2harmmean_hand',
#  'EDA_Functionals_power_Filt2mad_hand',
#  'EDA_Functionals_power_Filt2baseline_hand',
#  'Activity']

# %%
df = pd.read_csv('data.txt', header=None, names=label_list, na_values = 'N/A')#, set_flags(allows_duplicate_labels=False))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4480 entries, 0 to 4479
# Columns: 535 entries, Subject index (1-40) to Activity
# dtypes: float64(520), int64(14), object(1)
# memory usage: 18.3+ MB

# %%
df.head()
# Out:
#    Subject index (1-40)  ECG_original_mean  ECG_original_std  \
# 0                     1          -0.004125          0.254095
# 1                     1           0.031029          0.193761
# 2                     1           0.015678          0.182336
# 3                     1           0.014525          0.176636
# 4                     1           0.010349          0.179248
#
#    ECG_original_trimmean25  ECG_original_median  ECG_original_skewness  \
# 0                 0.001426             -0.01037              -0.538509
# 1                 0.012918             -0.00237               0.781415
# 2                -0.003028             -0.02337               0.881194
# 3                -0.006161             -0.02737               1.024900
# 4                -0.008526             -0.02737               0.935697
#
#    ECG_original_kurtosis  ECG_original_max  ECG_original_min  \
# 0                5.95534           1.04063          -1.37437
# 1                5.18794           0.98963          -0.71937
# 2                5.66530           0.87563          -0.71937
# 3                6.10968           0.91063          -0.71937
# 4                5.83902           0.91063          -0.75637
#
#    ECG_original_prctile25  ...  EDA_Functionals_power_Filt2kurtosis_hand  \
# 0                -0.10937  ...                                   1015.36
# 1                -0.08737  ...                                   1015.78
# 2                -0.08037  ...                                   1016.16
# 3                -0.08037  ...                                   1015.61
# 4                -0.08337  ...                                   1015.67
#
#    EDA_Functionals_power_Filt2max_hand  EDA_Functionals_power_Filt2min_hand  \
# 0                          717032000.0                             0.027384
# 1                          705854000.0                             0.016947
# 2                          627018000.0                             0.008129
# 3                          559748000.0                             0.007377
# 4                          484473000.0                             0.011448
#
#    EDA_Functionals_power_Filt2prctile25_hand  \
# 0                                    2.53425
# 1                                    2.51513
# 2                                    2.25959
# 3                                    2.13924
# 4                                    1.93595
#
#    EDA_Functionals_power_Filt2prctile75_hand  \
# 0                                    17.3882
# 1                                    16.5914
# 2                                    15.2312
# 3                                    14.4663
# 4                                    12.5493
#
#    EDA_Functionals_power_Filt2geomean(abs)_hand  \
# 0                                       8.05589
# 1                                       7.81769
# 2                                       7.11684
# 3                                       6.70236
# 4                                       6.08647
#
#    EDA_Functionals_power_Filt2harmmean_hand  \
# 0                                   1.80247
# 1                                   1.52349
# 2                                   1.25860
# 3                                   1.26643
# 4                                   1.22387
#
#    EDA_Functionals_power_Filt2mad_hand  \
# 0                            1413310.0
# 1                            1390180.0
# 2                            1234110.0
# 3                            1102720.0
# 4                             954322.0
#
#    EDA_Functionals_power_Filt2baseline_hand  Activity
# 0                                 3028080.0      .0f
# 1                                 3016420.0      .0f
# 2                                 3004430.0      .0f
# 3                                 2992170.0      .0f
# 4                                 2979610.0      .0f
#
# [5 rows x 535 columns]

# %% [markdown]
# # Changing the label col from object to numbers.

# %%
df.iloc[:,-1].unique()
# array(['\x01.0f', '\x03.0f', '\x02.0f', '\x04.0f'], dtype=object)

for index, rows in df.iterrows():
    if df.loc[index, 'Activity'] == '\x01.0f':
        df.loc[index, 'Activity'] = 1
    elif df.loc[index, 'Activity'] == '\x02.0f':
        df.loc[index, 'Activity'] = 2
    elif df.loc[index, 'Activity'] == '\x03.0f':
        df.loc[index, 'Activity'] = 3
    elif df.loc[index, 'Activity'] == '\x04.0f':
        df.loc[index, 'Activity'] = 4

# %% [markdown]
# # Checking for NA

# %%
for col in range(df.shape[1]):
    # YOUR CODE HERE
    n_miss = df.isnull().sum(axis=0)
    print('Column {} has {} missing values.'.format(col, n_miss.iloc[col]))
# No NA in dataset.
# Out:
# Column 0 has 0 missing values.
# Column 1 has 0 missing values.
# Column 2 has 0 missing values.
# Column 3 has 0 missing values.
# Column 4 has 0 missing values.
# Column 5 has 0 missing values.
# Column 6 has 0 missing values.
# Column 7 has 0 missing values.
# Column 8 has 0 missing values.
# Column 9 has 0 missing values.
# Column 10 has 0 missing values.
# Column 11 has 0 missing values.
# Column 12 has 0 missing values.
# Column 13 has 0 missing values.
# Column 14 has 0 missing values.
# Column 15 has 0 missing values.
# Column 16 has 0 missing values.
# Column 17 has 0 missing values.
# Column 18 has 0 missing values.
# Column 19 has 0 missing values.
# Column 20 has 0 missing values.
# Column 21 has 0 missing values.
# Column 22 has 0 missing values.
# Column 23 has 0 missing values.
# Column 24 has 0 missing values.
# Column 25 has 0 missing values.
# Column 26 has 0 missing values.
# Column 27 has 0 missing values.
# Column 28 has 0 missing values.
# Column 29 has 0 missing values.
# Column 30 has 0 missing values.
# Column 31 has 0 missing values.
# Column 32 has 0 missing values.
# Column 33 has 0 missing values.
# Column 34 has 0 missing values.
# Column 35 has 0 missing values.
# Column 36 has 0 missing values.
# Column 37 has 0 missing values.
# Column 38 has 0 missing values.
# Column 39 has 0 missing values.
# Column 40 has 0 missing values.
# Column 41 has 0 missing values.
# Column 42 has 0 missing values.
# Column 43 has 0 missing values.
# Column 44 has 0 missing values.
# Column 45 has 0 missing values.
# Column 46 has 0 missing values.
# Column 47 has 0 missing values.
# Column 48 has 0 missing values.
# Column 49 has 0 missing values.
# Column 50 has 0 missing values.
# Column 51 has 0 missing values.
# Column 52 has 0 missing values.
# Column 53 has 0 missing values.
# Column 54 has 0 missing values.
# Column 55 has 0 missing values.
# Column 56 has 0 missing values.
# Column 57 has 0 missing values.
# Column 58 has 0 missing values.
# Column 59 has 0 missing values.
# Column 60 has 0 missing values.
# Column 61 has 0 missing values.
# Column 62 has 0 missing values.
# Column 63 has 0 missing values.
# Column 64 has 0 missing values.
# Column 65 has 0 missing values.
# Column 66 has 0 missing values.
# Column 67 has 0 missing values.
# Column 68 has 0 missing values.
# Column 69 has 0 missing values.
# Column 70 has 0 missing values.
# Column 71 has 0 missing values.
# Column 72 has 0 missing values.
# Column 73 has 0 missing values.
# Column 74 has 0 missing values.
# Column 75 has 0 missing values.
# Column 76 has 0 missing values.
# Column 77 has 0 missing values.
# Column 78 has 0 missing values.
# Column 79 has 0 missing values.
# Column 80 has 0 missing values.
# Column 81 has 0 missing values.
# Column 82 has 0 missing values.
# Column 83 has 0 missing values.
# Column 84 has 0 missing values.
# Column 85 has 0 missing values.
# Column 86 has 0 missing values.
# Column 87 has 0 missing values.
# Column 88 has 0 missing values.
# Column 89 has 0 missing values.
# Column 90 has 0 missing values.
# Column 91 has 0 missing values.
# Column 92 has 0 missing values.
# Column 93 has 0 missing values.
# Column 94 has 0 missing values.
# Column 95 has 0 missing values.
# Column 96 has 0 missing values.
# Column 97 has 0 missing values.
# Column 98 has 0 missing values.
# Column 99 has 0 missing values.
# Column 100 has 0 missing values.
# Column 101 has 0 missing values.
# Column 102 has 0 missing values.
# Column 103 has 0 missing values.
# Column 104 has 0 missing values.
# Column 105 has 0 missing values.
# Column 106 has 0 missing values.
# Column 107 has 0 missing values.
# Column 108 has 0 missing values.
# Column 109 has 0 missing values.
# Column 110 has 0 missing values.
# Column 111 has 0 missing values.
# Column 112 has 0 missing values.
# Column 113 has 0 missing values.
# Column 114 has 0 missing values.
# Column 115 has 0 missing values.
# Column 116 has 0 missing values.
# Column 117 has 0 missing values.
# Column 118 has 0 missing values.
# Column 119 has 0 missing values.
# Column 120 has 0 missing values.
# Column 121 has 0 missing values.
# Column 122 has 0 missing values.
# Column 123 has 0 missing values.
# Column 124 has 0 missing values.
# Column 125 has 0 missing values.
# Column 126 has 0 missing values.
# Column 127 has 0 missing values.
# Column 128 has 0 missing values.
# Column 129 has 0 missing values.
# Column 130 has 0 missing values.
# Column 131 has 0 missing values.
# Column 132 has 0 missing values.
# Column 133 has 0 missing values.
# Column 134 has 0 missing values.
# Column 135 has 0 missing values.
# Column 136 has 0 missing values.
# Column 137 has 0 missing values.
# Column 138 has 0 missing values.
# Column 139 has 0 missing values.
# Column 140 has 0 missing values.
# Column 141 has 0 missing values.
# Column 142 has 0 missing values.
# Column 143 has 0 missing values.
# Column 144 has 0 missing values.
# Column 145 has 0 missing values.
# Column 146 has 0 missing values.
# Column 147 has 0 missing values.
# Column 148 has 0 missing values.
# Column 149 has 0 missing values.
# Column 150 has 0 missing values.
# Column 151 has 0 missing values.
# Column 152 has 0 missing values.
# Column 153 has 0 missing values.
# Column 154 has 0 missing values.
# Column 155 has 0 missing values.
# Column 156 has 0 missing values.
# Column 157 has 0 missing values.
# Column 158 has 0 missing values.
# Column 159 has 0 missing values.
# Column 160 has 0 missing values.
# Column 161 has 0 missing values.
# Column 162 has 0 missing values.
# Column 163 has 0 missing values.
# Column 164 has 0 missing values.
# Column 165 has 0 missing values.
# Column 166 has 0 missing values.
# Column 167 has 0 missing values.
# Column 168 has 0 missing values.
# Column 169 has 0 missing values.
# Column 170 has 0 missing values.
# Column 171 has 0 missing values.
# Column 172 has 0 missing values.
# Column 173 has 0 missing values.
# Column 174 has 0 missing values.
# Column 175 has 0 missing values.
# Column 176 has 0 missing values.
# Column 177 has 0 missing values.
# Column 178 has 0 missing values.
# Column 179 has 0 missing values.
# Column 180 has 0 missing values.
# Column 181 has 0 missing values.
# Column 182 has 0 missing values.
# Column 183 has 0 missing values.
# Column 184 has 0 missing values.
# Column 185 has 0 missing values.
# Column 186 has 0 missing values.
# Column 187 has 0 missing values.
# Column 188 has 0 missing values.
# Column 189 has 0 missing values.
# Column 190 has 0 missing values.
# Column 191 has 0 missing values.
# Column 192 has 0 missing values.
# Column 193 has 0 missing values.
# Column 194 has 0 missing values.
# Column 195 has 0 missing values.
# Column 196 has 0 missing values.
# Column 197 has 0 missing values.
# Column 198 has 0 missing values.
# Column 199 has 0 missing values.
# Column 200 has 0 missing values.
# Column 201 has 0 missing values.
# Column 202 has 0 missing values.
# Column 203 has 0 missing values.
# Column 204 has 0 missing values.
# Column 205 has 0 missing values.
# Column 206 has 0 missing values.
# Column 207 has 0 missing values.
# Column 208 has 0 missing values.
# Column 209 has 0 missing values.
# Column 210 has 0 missing values.
# Column 211 has 0 missing values.
# Column 212 has 0 missing values.
# Column 213 has 0 missing values.
# Column 214 has 0 missing values.
# Column 215 has 0 missing values.
# Column 216 has 0 missing values.
# Column 217 has 0 missing values.
# Column 218 has 0 missing values.
# Column 219 has 0 missing values.
# Column 220 has 0 missing values.
# Column 221 has 0 missing values.
# Column 222 has 0 missing values.
# Column 223 has 0 missing values.
# Column 224 has 0 missing values.
# Column 225 has 0 missing values.
# Column 226 has 0 missing values.
# Column 227 has 0 missing values.
# Column 228 has 0 missing values.
# Column 229 has 0 missing values.
# Column 230 has 0 missing values.
# Column 231 has 0 missing values.
# Column 232 has 0 missing values.
# Column 233 has 0 missing values.
# Column 234 has 0 missing values.
# Column 235 has 0 missing values.
# Column 236 has 0 missing values.
# Column 237 has 0 missing values.
# Column 238 has 0 missing values.
# Column 239 has 0 missing values.
# Column 240 has 0 missing values.
# Column 241 has 0 missing values.
# Column 242 has 0 missing values.
# Column 243 has 0 missing values.
# Column 244 has 0 missing values.
# Column 245 has 0 missing values.
# Column 246 has 0 missing values.
# Column 247 has 0 missing values.
# Column 248 has 0 missing values.
# Column 249 has 0 missing values.
# Column 250 has 0 missing values.
# Column 251 has 0 missing values.
# Column 252 has 0 missing values.
# Column 253 has 0 missing values.
# Column 254 has 0 missing values.
# Column 255 has 0 missing values.
# Column 256 has 0 missing values.
# Column 257 has 0 missing values.
# Column 258 has 0 missing values.
# Column 259 has 0 missing values.
# Column 260 has 0 missing values.
# Column 261 has 0 missing values.
# Column 262 has 0 missing values.
# Column 263 has 0 missing values.
# Column 264 has 0 missing values.
# Column 265 has 0 missing values.
# Column 266 has 0 missing values.
# Column 267 has 0 missing values.
# Column 268 has 0 missing values.
# Column 269 has 0 missing values.
# Column 270 has 0 missing values.
# Column 271 has 0 missing values.
# Column 272 has 0 missing values.
# Column 273 has 0 missing values.
# Column 274 has 0 missing values.
# Column 275 has 0 missing values.
# Column 276 has 0 missing values.
# Column 277 has 0 missing values.
# Column 278 has 0 missing values.
# Column 279 has 0 missing values.
# Column 280 has 0 missing values.
# Column 281 has 0 missing values.
# Column 282 has 0 missing values.
# Column 283 has 0 missing values.
# Column 284 has 0 missing values.
# Column 285 has 0 missing values.
# Column 286 has 0 missing values.
# Column 287 has 0 missing values.
# Column 288 has 0 missing values.
# Column 289 has 0 missing values.
# Column 290 has 0 missing values.
# Column 291 has 0 missing values.
# Column 292 has 0 missing values.
# Column 293 has 0 missing values.
# Column 294 has 0 missing values.
# Column 295 has 0 missing values.
# Column 296 has 0 missing values.
# Column 297 has 0 missing values.
# Column 298 has 0 missing values.
# Column 299 has 0 missing values.
# Column 300 has 0 missing values.
# Column 301 has 0 missing values.
# Column 302 has 0 missing values.
# Column 303 has 0 missing values.
# Column 304 has 0 missing values.
# Column 305 has 0 missing values.
# Column 306 has 0 missing values.
# Column 307 has 0 missing values.
# Column 308 has 0 missing values.
# Column 309 has 0 missing values.
# Column 310 has 0 missing values.
# Column 311 has 0 missing values.
# Column 312 has 0 missing values.
# Column 313 has 0 missing values.
# Column 314 has 0 missing values.
# Column 315 has 0 missing values.
# Column 316 has 0 missing values.
# Column 317 has 0 missing values.
# Column 318 has 0 missing values.
# Column 319 has 0 missing values.
# Column 320 has 0 missing values.
# Column 321 has 0 missing values.
# Column 322 has 0 missing values.
# Column 323 has 0 missing values.
# Column 324 has 0 missing values.
# Column 325 has 0 missing values.
# Column 326 has 0 missing values.
# Column 327 has 0 missing values.
# Column 328 has 0 missing values.
# Column 329 has 0 missing values.
# Column 330 has 0 missing values.
# Column 331 has 0 missing values.
# Column 332 has 0 missing values.
# Column 333 has 0 missing values.
# Column 334 has 0 missing values.
# Column 335 has 0 missing values.
# Column 336 has 0 missing values.
# Column 337 has 0 missing values.
# Column 338 has 0 missing values.
# Column 339 has 0 missing values.
# Column 340 has 0 missing values.
# Column 341 has 0 missing values.
# Column 342 has 0 missing values.
# Column 343 has 0 missing values.
# Column 344 has 0 missing values.
# Column 345 has 0 missing values.
# Column 346 has 0 missing values.
# Column 347 has 0 missing values.
# Column 348 has 0 missing values.
# Column 349 has 0 missing values.
# Column 350 has 0 missing values.
# Column 351 has 0 missing values.
# Column 352 has 0 missing values.
# Column 353 has 0 missing values.
# Column 354 has 0 missing values.
# Column 355 has 0 missing values.
# Column 356 has 0 missing values.
# Column 357 has 0 missing values.
# Column 358 has 0 missing values.
# Column 359 has 0 missing values.
# Column 360 has 0 missing values.
# Column 361 has 0 missing values.
# Column 362 has 0 missing values.
# Column 363 has 0 missing values.
# Column 364 has 0 missing values.
# Column 365 has 0 missing values.
# Column 366 has 0 missing values.
# Column 367 has 0 missing values.
# Column 368 has 0 missing values.
# Column 369 has 0 missing values.
# Column 370 has 0 missing values.
# Column 371 has 0 missing values.
# Column 372 has 0 missing values.
# Column 373 has 0 missing values.
# Column 374 has 0 missing values.
# Column 375 has 0 missing values.
# Column 376 has 0 missing values.
# Column 377 has 0 missing values.
# Column 378 has 0 missing values.
# Column 379 has 0 missing values.
# Column 380 has 0 missing values.
# Column 381 has 0 missing values.
# Column 382 has 0 missing values.
# Column 383 has 0 missing values.
# Column 384 has 0 missing values.
# Column 385 has 0 missing values.
# Column 386 has 0 missing values.
# Column 387 has 0 missing values.
# Column 388 has 0 missing values.
# Column 389 has 0 missing values.
# Column 390 has 0 missing values.
# Column 391 has 0 missing values.
# Column 392 has 0 missing values.
# Column 393 has 0 missing values.
# Column 394 has 0 missing values.
# Column 395 has 0 missing values.
# Column 396 has 0 missing values.
# Column 397 has 0 missing values.
# Column 398 has 0 missing values.
# Column 399 has 0 missing values.
# Column 400 has 0 missing values.
# Column 401 has 0 missing values.
# Column 402 has 0 missing values.
# Column 403 has 0 missing values.
# Column 404 has 0 missing values.
# Column 405 has 0 missing values.
# Column 406 has 0 missing values.
# Column 407 has 0 missing values.
# Column 408 has 0 missing values.
# Column 409 has 0 missing values.
# Column 410 has 0 missing values.
# Column 411 has 0 missing values.
# Column 412 has 0 missing values.
# Column 413 has 0 missing values.
# Column 414 has 0 missing values.
# Column 415 has 0 missing values.
# Column 416 has 0 missing values.
# Column 417 has 0 missing values.
# Column 418 has 0 missing values.
# Column 419 has 0 missing values.
# Column 420 has 0 missing values.
# Column 421 has 0 missing values.
# Column 422 has 0 missing values.
# Column 423 has 0 missing values.
# Column 424 has 0 missing values.
# Column 425 has 0 missing values.
# Column 426 has 0 missing values.
# Column 427 has 0 missing values.
# Column 428 has 0 missing values.
# Column 429 has 0 missing values.
# Column 430 has 0 missing values.
# Column 431 has 0 missing values.
# Column 432 has 0 missing values.
# Column 433 has 0 missing values.
# Column 434 has 0 missing values.
# Column 435 has 0 missing values.
# Column 436 has 0 missing values.
# Column 437 has 0 missing values.
# Column 438 has 0 missing values.
# Column 439 has 0 missing values.
# Column 440 has 0 missing values.
# Column 441 has 0 missing values.
# Column 442 has 0 missing values.
# Column 443 has 0 missing values.
# Column 444 has 0 missing values.
# Column 445 has 0 missing values.
# Column 446 has 0 missing values.
# Column 447 has 0 missing values.
# Column 448 has 0 missing values.
# Column 449 has 0 missing values.
# Column 450 has 0 missing values.
# Column 451 has 0 missing values.
# Column 452 has 0 missing values.
# Column 453 has 0 missing values.
# Column 454 has 0 missing values.
# Column 455 has 0 missing values.
# Column 456 has 0 missing values.
# Column 457 has 0 missing values.
# Column 458 has 0 missing values.
# Column 459 has 0 missing values.
# Column 460 has 0 missing values.
# Column 461 has 0 missing values.
# Column 462 has 0 missing values.
# Column 463 has 0 missing values.
# Column 464 has 0 missing values.
# Column 465 has 0 missing values.
# Column 466 has 0 missing values.
# Column 467 has 0 missing values.
# Column 468 has 0 missing values.
# Column 469 has 0 missing values.
# Column 470 has 0 missing values.
# Column 471 has 0 missing values.
# Column 472 has 0 missing values.
# Column 473 has 0 missing values.
# Column 474 has 0 missing values.
# Column 475 has 0 missing values.
# Column 476 has 0 missing values.
# Column 477 has 0 missing values.
# Column 478 has 0 missing values.
# Column 479 has 0 missing values.
# Column 480 has 0 missing values.
# Column 481 has 0 missing values.
# Column 482 has 0 missing values.
# Column 483 has 0 missing values.
# Column 484 has 0 missing values.
# Column 485 has 0 missing values.
# Column 486 has 0 missing values.
# Column 487 has 0 missing values.
# Column 488 has 0 missing values.
# Column 489 has 0 missing values.
# Column 490 has 0 missing values.
# Column 491 has 0 missing values.
# Column 492 has 0 missing values.
# Column 493 has 0 missing values.
# Column 494 has 0 missing values.
# Column 495 has 0 missing values.
# Column 496 has 0 missing values.
# Column 497 has 0 missing values.
# Column 498 has 0 missing values.
# Column 499 has 0 missing values.
# Column 500 has 0 missing values.
# Column 501 has 0 missing values.
# Column 502 has 0 missing values.
# Column 503 has 0 missing values.
# Column 504 has 0 missing values.
# Column 505 has 0 missing values.
# Column 506 has 0 missing values.
# Column 507 has 0 missing values.
# Column 508 has 0 missing values.
# Column 509 has 0 missing values.
# Column 510 has 0 missing values.
# Column 511 has 0 missing values.
# Column 512 has 0 missing values.
# Column 513 has 0 missing values.
# Column 514 has 0 missing values.
# Column 515 has 0 missing values.
# Column 516 has 0 missing values.
# Column 517 has 0 missing values.
# Column 518 has 0 missing values.
# Column 519 has 0 missing values.
# Column 520 has 0 missing values.
# Column 521 has 0 missing values.
# Column 522 has 0 missing values.
# Column 523 has 0 missing values.
# Column 524 has 0 missing values.
# Column 525 has 0 missing values.
# Column 526 has 0 missing values.
# Column 527 has 0 missing values.
# Column 528 has 0 missing values.
# Column 529 has 0 missing values.
# Column 530 has 0 missing values.
# Column 531 has 0 missing values.
# Column 532 has 0 missing values.
# Column 533 has 0 missing values.
# Column 534 has 0 missing values.

# %% [markdown]
# * Do we have to normalize all data?

# %% [markdown]
# # Summary statistics:

# %% [markdown]
# * The first column correspond to the index of the subject.
# * The next 174 attributes are statistics extracted from the ECG signal.
# * The next 151 attributes are features extracted from the TEB signal.
# * The next 104 attributes come from the EDA measured in the arm.
# * The next 104 ones from the EDA in the hand.
# * The last attribute is the pattern class, that is, the corresponding activity: 1-neutral, 2-emotional, 3-mental and 4-physical.

# %% [markdown]
# Idear:
#  * Group by subject
#  * Group by Activity
#  * https://www.youtube.com/watch?v=BJ-FIGzKEaA
#  * https://www.youtube.com/watch?v=lUI6VMj43PE&ab_channel=KGPTalkie

# %%
df['Subject index (1-40)']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 4475    40
# 4476    40
# 4477    40
# 4478    40
# 4479    40
# Name: Subject index (1-40), Length: 4480, dtype: int64

# %%
plt.hist(df.iloc[:,-1], bins=1)
plt.show()
plt.hist(df['Subject index (1-40)'], bins=1)
plt.show()

# %%
mean_list = list([col for col in df.columns if "mean" in col])
median_list = list([col for col in df.columns if "median" in col])

# def summarystat(df, list, group='Subject index (1-40)'):
#     df[list].groupby(df[group]).describe()

#print(df[mean_list].groupby(df.iloc[:,-1]).mean())
print(df[median_list].groupby(df.iloc[:,-1]).hist())
# Out:
# Activity
# 1    [[AxesSubplot(0.125,0.779333;0.103333x0.100667...
# 2    [[AxesSubplot(0.125,0.779333;0.103333x0.100667...
# 3    [[AxesSubplot(0.125,0.779333;0.103333x0.100667...
# 4    [[AxesSubplot(0.125,0.779333;0.103333x0.100667...
# dtype: object

# %% [markdown]
# # Visualization:

# %%
plt.hist(df['ECG_original_mean'].groupby(df.iloc[:,-1]).mean())
plt.show()
